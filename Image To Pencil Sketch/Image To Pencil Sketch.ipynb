# %% [markdown]
# # LetsGrowMore Beginner Level Task: Image To Pencil Sketch
# Author : AVIRUP MAZUMDER

# %%
import cv2
import matplotlib.pyplot as plt

# %%
img = cv2.imread('messi5.jpg',-1)
# plt.figure(figsize=(8,8))
plt.title("Original Image")
plt.imshow(img)

# %%
print(img.shape)
grey = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
plt.imshow(grey,cmap="gray")
plt.title("GrayScale Image")
# Out:
# (342, 548, 3)
# Text(0.5, 1.0, 'GrayScale Image')

# %%
img_invert = cv2.bitwise_not(grey)
plt.imshow(img_invert,cmap="gray")
plt.title("Inverted Image")
# Out:
# Text(0.5, 1.0, 'Inverted Image')

# %%
img_smoothing = cv2.GaussianBlur(img_invert, (21, 21),sigmaX=0, sigmaY=0)
plt.imshow(img_smoothing,cmap="gray")
plt.title("Smoothen Image")
# Out:
# Text(0.5, 1.0, 'Smoothen Image')

# %%
final = cv2.divide(grey, 255 - img_smoothing, scale=255)
plt.imshow(final,cmap="gray")
plt.title("Final Sketch Image")
# Out:
# Text(0.5, 1.0, 'Final Sketch Image')

# %%
plt.figure(figsize=(20,20))
# plt.plot()

plt.subplot(1,5,1)
plt.title("Original Image")
plt.imshow(img)

plt.subplot(1,5,2)
plt.imshow(grey,cmap="gray")
plt.title("GrayScale Image")

plt.subplot(1,5,3)
plt.imshow(img_invert,cmap="gray")
plt.title("Inverted Image")

plt.subplot(1,5,4)
plt.imshow(img_smoothing,cmap="gray")
plt.title("Smoothen Image")

plt.subplot(1,5,5)
plt.imshow(final,cmap="gray")
plt.title("Final Sketch Image")
# Out:
# Text(0.5, 1.0, 'Final Sketch Image')
